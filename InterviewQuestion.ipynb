# %% [markdown]
# <a href="https://colab.research.google.com/github/SeanMuInCa/learn_python/blob/master/InterviewQuestion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext sql

# %%
# %sql sqlite:///B_database.db

# %% [markdown]
# There is a murder case in **Vancouver** and we had **2 witnesses**.
#
# The **1st witness** lives at the last house on "**Northwestern Dr**".
#
# The 2nd witness Annabel, lives on "Franklin Ave".
#
# With this clue and the schema below, find the witnesses and their corresponding interview. Then do the investigation and find the name of the murderer.
#
# **Name of the murderer: **_____________________________________________________

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# %%sql
# select * from interview
# Out:
#  * sqlite:///B_database.db
# (sqlite3.OperationalError) no such table: interview
# [SQL: select * from interview]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# 2018,1,15
# 14887,Morty Schapiro,118009,4919,Northwestern Dr,111564949
# 16371,Annabel Miller,490173,103,Franklin Ave,318771143
#
# I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".
#
# I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.
#
# 48Z7A
# 48Z55
