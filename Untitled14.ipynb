# %% [markdown]
# <a href="https://colab.research.google.com/github/SeanMuInCa/learn_python/blob/master/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
img = cv2.imread("card.JPG")

# %%
width,height = 400,600
pts1 = np.float32([[111,219],[287,188],[154,482],[352,440]])
pts2 = np.float32([[0,0],[width,0],[0,height],[width,height]])
matrix = cv2.getPerspectiveTransform(pts1,pts2)
imgOutput = cv2.warpPerspective(img,matrix,(width,height))


cv2_imshow(img)
cv2_imshow(imgOutput)

cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=660x691>
# <PIL.Image.Image image mode=RGB size=400x600>
# -1

# %%
import cv2
import matplotlib.pyplot as plt

# 加载图像
img = cv2.imread('card.JPG')

# 检查图像是否成功加载
if img is None:
    print("Error: 图像未成功加载。请检查文件路径。")
else:
    # 将 BGR 图像转换为 RGB 格式
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # 显示图像
    fig, ax = plt.subplots()
    ax.imshow(img_rgb)

    # 鼠标点击事件处理函数
    def onclick(event):
        if event.xdata is not None and event.ydata is not None:
            x = int(event.xdata)
            y = int(event.ydata)
            print(f'坐标: ({x}, {y})')

    # 连接点击事件
    fig.canvas.mpl_connect('button_press_event', onclick)

    plt.show()
# Out:
# <div id='9437371c-55fb-4d50-ac3d-8c09d575b0cf'></div>
